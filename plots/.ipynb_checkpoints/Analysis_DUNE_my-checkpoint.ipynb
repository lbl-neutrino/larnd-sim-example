# %%
from platform import python_version
print(python_version())
# Out:
# 3.11.7

# %%
import os
import re
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from datetime import datetime

# %%
# Initialize global variables
total_files = 0
total_files_processed = 0
total_elasped_time = 0
total_files_failed = 0
elapsed_times = []
files_without_elapsed_time = []

output_file_path = "FailedJob_160.txt"

def process_log_files(directory):
    global total_files, total_files_processed, total_elasped_time, total_files_failed, elapsed_times, files_without_elapsed_time
    file_pattern = re.compile(r'edep-sim input file:\s*(.+)')
    time_pattern = re.compile(r'Elapsed time:\s*([\d.]+)\s*s')

    for filename in os.listdir(directory):
        if filename.endswith(".log"):
            with open(os.path.join(directory, filename), 'r') as file:
                input_file_found = False
                elapsed_time_found = False
                for line in file:
                    file_match = file_pattern.search(line)
                    if file_match:
                        full_path = file_match.group(1)
                        input_file = os.path.basename(full_path)  # Extract file name from the full path
                        # directory_path = os.path.dirname(full_path)
                        # full_path = os.path.join(directory_path, input_file)
                        input_file_found = True
                        total_files_processed += 1

                    time_match = time_pattern.search(line)
                    if time_match:
                        elapsed_time = float(time_match.group(1))  # No conversion to minutes
                        elapsed_times.append(elapsed_time)
                        elapsed_time_found = True
                        total_elasped_time += 1
                        #print(f"{input_file}: Elapsed time: {elapsed_time:.2f} sec")
                
                if not elapsed_time_found and input_file_found:
                    #files_without_elapsed_time.append(input_file)
                    files_without_elapsed_time.append(full_path)

    # Calculate statistics for Job Duration in seconds
    if elapsed_times:
        mean_job_duration = np.mean(elapsed_times)
        median_job_duration = np.median(elapsed_times)
        stdev_job_duration = np.std(elapsed_times)
        min_job_duration = np.min(elapsed_times)
        max_job_duration = np.max(elapsed_times)
    else:
        mean_job_duration = median_job_duration = stdev_job_duration = min_job_duration = max_job_duration = 0.0

    total_files = total_files_processed
    total_files_failed = total_files - total_elasped_time
    print("\n********** Jobs Information **********")
    print(f"Total number of input files processed: {total_files}")
    print(f"Total number of Jobs completed: {total_elasped_time}")
    print(f"Total number of Jobs failed: {total_files_failed}")

    print("\n********** Statistics **********")
    print(f"Mean Job Duration: {mean_job_duration:.2f} sec")
    print(f"Median Job Duration: {median_job_duration:.2f} sec")
    print(f"Standard Deviation of Job Duration: {stdev_job_duration:.2f} sec")
    print(f"Minimum Job Duration: {min_job_duration:.2f} sec")
    print(f"Maximum Job Duration: {max_job_duration:.2f} sec")

    # # Print files without elapsed time
    # if files_without_elapsed_time:
    #     #print("\nFiles without 'Elapsed time':")
    #     print("\nFailed Job Input Files:")
    #     for file in files_without_elapsed_time:
    #         print(file)

folder_path = '/pscratch/sd/m/madan12/DUNE/nesap-develop/larnd-sim-output-80GB/'
process_log_files(folder_path)

# Sort the files without elapsed time
files_without_elapsed_time.sort()

# Open the file in write mode ('w')
with open(output_file_path, "w") as output_file:
    # Write sorted files without elapsed time to the file
    if files_without_elapsed_time:
        output_file.write("Files without 'Elapsed time' (sorted):\n")
        for file in files_without_elapsed_time:
            output_file.write(file + "\n")

# Print a message indicating that the output has been written to the file
print(f"Output has been written to '{output_file_path}'")
# Out:
# ********** Jobs Information **********
# Total number of input files processed: 1000
# Total number of Jobs completed: 840
# Total number of Jobs failed: 160
#
# ********** Statistics **********
# Mean Job Duration: 1161.80 sec
# Median Job Duration: 1160.80 sec
# Standard Deviation of Job Duration: 36.09 sec
# Minimum Job Duration: 1058.58 sec
# Maximum Job Duration: 1339.71 sec
# Output has been written to 'FailedJob_160.txt'

# %%
######## This in sec #########
# # Assuming 'elapsed_times' contains the job durations from the processed log files
# if elapsed_times:
#     # Filter job duration values greater than 0
#     valid_job_durations = [duration for duration in elapsed_times if duration > 0]

#     # Create the plot
#     plt.figure(figsize=(10, 6))
#     sns.histplot(valid_job_durations, bins=100, kde=True)  # Set bins or let seaborn decide

#     plt.xlabel('Job Duration [seconds]', fontsize=20)
#     #plt.xlim(200, 400)
#     plt.ylabel('Number of Tasks', fontsize=20)
#     #plt.title('Histogram of Job Durations', fontsize=20)

#     # Set font size for the tick labels on both axes
#     plt.tick_params(axis='both', labelsize=16)
    
#     # Add statistics text to the plot
#     stats_text_job_duration = (
#         f"Mean: {np.mean(valid_job_durations):.2f} sec\n"
#         f"Median: {np.median(valid_job_durations):.2f} sec\n"
#         f"StDev: {np.std(valid_job_durations):.2f} sec\n"
#         f"Min: {np.min(valid_job_durations):.2f} sec\n"
#         f"Max: {np.max(valid_job_durations):.2f} sec\n"
#         f"\n"
#         f"Total Num. of Tasks: {total_files}\n"
#         f"Num. Failed Tasks: {total_files_failed}"
#     )
#     plt.text(0.65, 0.6, stats_text_job_duration, transform=plt.gca().transAxes, bbox=dict(facecolor='white', alpha=0.5, edgecolor='none'), fontsize=14)
    
#     # Display and save the plot
#     plot = os.path.join(folder_path, 'DUNE_job_duration.png')
#     plt.savefig(plot, dpi=200)
#     plt.show()

# else:
#     print("No job duration data available to plot.")

######## This in min #########
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'elapsed_times' contains the job durations from the processed log files
if elapsed_times:
    # Filter job duration values greater than 0 and convert them to minutes
    elapsed_times_min = [duration / 60 for duration in elapsed_times if duration > 0]

    # Create the plot
    plt.figure(figsize=(10, 6))
    sns.histplot(elapsed_times_min, bins=100, kde=True)  # Set bins or let seaborn decide

    plt.xlabel('elapsed_times [minutes]', fontsize=20)
    plt.xlim(17, 23)
    plt.ylabel('Number of Tasks', fontsize=20)

    # Set font size for the tick labels on both axes
    plt.tick_params(axis='both', labelsize=16)
    
    # Add statistics text to the plot
    stats_text_job_duration = (
        f"Mean: {np.mean(elapsed_times_min):.2f} min\n"
        f"Median: {np.median(elapsed_times_min):.2f} min\n"
        f"StDev: {np.std(elapsed_times_min):.2f} min\n"
        f"Min: {np.min(elapsed_times_min):.2f} min\n"
        f"Max: {np.max(elapsed_times_min):.2f} min\n"
        f"\n"
        f"Total Num. of Tasks: {total_files}\n"
        f"Num. Failed Tasks: {total_files_failed}"
    )
    plt.text(0.65, 0.6, stats_text_job_duration, transform=plt.gca().transAxes, bbox=dict(facecolor='white', alpha=0.5, edgecolor='none'), fontsize=14)
    plt.grid(True)
    # Display and save the plot
    #plot = os.path.join(folder_path, 'DUNE_job_duration.png')
    plot = 'DUNE_elasped_time.png'
    plt.savefig(plot, dpi=200)
    plt.show()

else:
    print("No elapsed_times_min data available to plot.")

# %%
######## This in sec #########
# import os

# def check_host_for_long_tasks(log_file_path):
#     filename = os.path.basename(log_file_path)  # Extract the filename once at the beginning

#     with open(log_file_path, 'r') as file:
#         host_name = None
#         elapsed_time_over = False
#         for line in file:
#             if 'Processing file:' in line:
#                 parts = line.split(',')
#                 # Extract the host name directly from the predefined position
#                 host_name = parts[5].split(':')[-1].strip()

#             elif 'Elapsed time:' in line:
#                 try:
#                     # Convert the elapsed time to float and check if it's greater than 350 seconds
#                     elapsed_time = float(line.split(': ')[1].strip().split(' ')[0])
#                     if elapsed_time > 1250:
#                         elapsed_time_over = True
#                         # Break if both host name and elapsed time condition are met
#                         if host_name is not None:
#                             print(f'Host name: {host_name} for tasks longer than 1250 seconds in file {filename}')
#                             break
#                 except ValueError:
#                     # Handle cases where the conversion to float fails
#                     #print(f"Error parsing elapsed time in file {filename}: {line}")
#                     print(f"Error parsing elapsed time in file {log_file_path}: {line}")

# def process_all_logs(directory):
#     for filename in os.listdir(directory):
#         if filename.endswith('.log'):  # Assuming all log files end with .log
#             log_file_path = os.path.join(directory, filename)
#             check_host_for_long_tasks(log_file_path)

# # Directory path containing the log files
# folder_path = '/pscratch/sd/m/madan12/DUNE/nesap-develop/larnd-sim-output-80GB/'
# process_all_logs(folder_path)


######## This in min #########
import os

# Define the threshold for elapsed time in minutes
elapsed_time_threshold_min = 20.8

def check_host_for_long_tasks(log_file_path):
    filename = os.path.basename(log_file_path)  # Extract the filename once at the beginning

    with open(log_file_path, 'r') as file:
        host_name = None
        for line in file:
            if 'Processing file:' in line:
                parts = line.split(',')
                # Extract the host name directly from the predefined position
                host_name = parts[5].split(':')[-1].strip()

            elif 'Elapsed time:' in line:
                try:
                    # Convert the elapsed time to float and then to minutes
                    elapsed_time_sec = float(line.split(': ')[1].strip().split(' ')[0])
                    elapsed_time_min = elapsed_time_sec / 60
                    # Check if the elapsed time is greater than the threshold
                    if elapsed_time_min > elapsed_time_threshold_min:
                        # Break if both host name and elapsed time condition are met
                        if host_name is not None:
                            print(f'Host name: {host_name} for tasks longer than {elapsed_time_threshold_min} minutes in file {filename}')
                            break
                except ValueError:
                    # Handle cases where the conversion to float fails
                    print(f"Error parsing elapsed time in file {log_file_path}: {line}")

def process_all_logs(directory):
    for filename in os.listdir(directory):
        if filename.endswith('.log'):  # Assuming all log files end with .log
            log_file_path = os.path.join(directory, filename)
            check_host_for_long_tasks(log_file_path)

# Directory path containing the log files
folder_path = '/pscratch/sd/m/madan12/DUNE/nesap-develop/larnd-sim-output-80GB/'
process_all_logs(folder_path)
# Out:
# Host name: nid008493 for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000100.EDEPSIM_2024-06-04_12:43:12_4689_26449533.log
# Host name: nid008584 for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000321.EDEPSIM_2024-06-04_13:04:57_7526_26449534.log
# Host name: nid008488 for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000070.EDEPSIM_2024-06-04_12:43:13_4136_26449533.log
# Host name: nid008405 for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000030.EDEPSIM_2024-06-04_12:43:12_4032_26449533.log
# Host name: nid008485 for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000576.EDEPSIM_2024-06-04_14:47:35_7995_26450026.log
# Host name: nid008488 for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000064.EDEPSIM_2024-06-04_13:54:55_2554_26449533.log
# Host name: nid008488 for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000040.EDEPSIM_2024-06-04_12:43:13_5190_26449533.log
# Host name: nid008493 for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000080.EDEPSIM_2024-06-04_12:43:12_4320_26449533.log
# Host name: nid008493 for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000110.EDEPSIM_2024-06-04_12:43:12_3270_26449533.log
# Host name: nid008561 for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000285.EDEPSIM_2024-06-04_14:23:28_9963_26449534.log
# Host name: nid008404 for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000477.EDEPSIM_2024-06-04_14:57:53_7585_26450026.log
# Host name: nid008572 for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000141.EDEPSIM_2024-06-04_13:03:52_5978_26449533.log
# Host name: nid008284 for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000422.EDEPSIM_2024-06-04_13:36:45_8607_26450026.log

# %%
# ######## This in sec #########
# import os

# def check_host_for_long_tasks(log_file_path):
#     filename = os.path.basename(log_file_path)  # Extract the filename once at the beginning

#     with open(log_file_path, 'r') as file:
#         host_name = None
#         task_start_time = None
#         elapsed_time_over = False
#         for line in file:
#             if 'Processing file:' in line:
#                 parts = line.split(',')
#                 # Extract the host name directly from the predefined position
#                 host_name = parts[5].split(':')[-1].strip()
#                 task_start_time = parts[3].split('Task Start Time: ')[1].strip()
            

#             elif 'Elapsed time:' in line:
#                 try:
#                     # Convert the elapsed time to float and check if it's greater than 325 seconds
#                     elapsed_time = float(line.split(': ')[1].strip().split(' ')[0])
#                     if elapsed_time > 1250:
#                         elapsed_time_over = True
#                         # Print if both host name, start time, and elapsed time condition are met
#                         if host_name is not None and task_start_time is not None:
#                             print(f'Host name: {host_name}, Task start time: {task_start_time}, for tasks longer than 1250 sec in file {filename}')
#                             break
#                 except ValueError:
#                     # Handle cases where the conversion to float fails
#                     print(f"Error parsing elapsed time in file {log_file_path}: {line}")

# def process_all_logs(directory):
#     for filename in os.listdir(directory):
#         if filename.endswith('.log'):  # Assuming all log files end with .log
#             log_file_path = os.path.join(directory, filename)
#             check_host_for_long_tasks(log_file_path)

# # Directory path containing the log files
# folder_path = '/pscratch/sd/m/madan12/DUNE/nesap-develop/larnd-sim-output-80GB/'
# process_all_logs(folder_path)


######## This in min #########
import os

# Define the threshold for elapsed time in minutes
elapsed_time_threshold_min = 20.8

def check_host_for_long_tasks(log_file_path):
    filename = os.path.basename(log_file_path)  # Extract the filename once at the beginning

    with open(log_file_path, 'r') as file:
        host_name = None
        task_start_time = None
        for line in file:
            if 'Processing file:' in line:
                parts = line.split(',')
                # Extract the host name directly from the predefined position
                host_name = parts[5].split(':')[-1].strip()
                task_start_time = parts[3].split('Task Start Time: ')[1].strip()

            elif 'Elapsed time:' in line:
                try:
                    # Convert the elapsed time to float and then to minutes
                    elapsed_time_sec = float(line.split(': ')[1].strip().split(' ')[0])
                    elapsed_time_min = elapsed_time_sec / 60
                    # Check if the elapsed time is greater than the threshold
                    if elapsed_time_min > elapsed_time_threshold_min:
                        # Print if both host name, start time, and elapsed time condition are met
                        if host_name is not None and task_start_time is not None:
                            print(f'Host name: {host_name}, Task start time: {task_start_time}, for tasks longer than {elapsed_time_threshold_min} minutes in file {filename}')
                            break
                except ValueError:
                    # Handle cases where the conversion to float fails
                    print(f"Error parsing elapsed time in file {log_file_path}: {line}")

def process_all_logs(directory):
    for filename in os.listdir(directory):
        if filename.endswith('.log'):  # Assuming all log files end with .log
            log_file_path = os.path.join(directory, filename)
            check_host_for_long_tasks(log_file_path)

# Directory path containing the log files
folder_path = '/pscratch/sd/m/madan12/DUNE/nesap-develop/larnd-sim-output-80GB/'
process_all_logs(folder_path)
# Out:
# Host name: nid008493, Task start time: 2024-06-04_12:43:12, for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000100.EDEPSIM_2024-06-04_12:43:12_4689_26449533.log
# Host name: nid008584, Task start time: 2024-06-04_13:04:57, for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000321.EDEPSIM_2024-06-04_13:04:57_7526_26449534.log
# Host name: nid008488, Task start time: 2024-06-04_12:43:13, for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000070.EDEPSIM_2024-06-04_12:43:13_4136_26449533.log
# Host name: nid008405, Task start time: 2024-06-04_12:43:12, for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000030.EDEPSIM_2024-06-04_12:43:12_4032_26449533.log
# Host name: nid008485, Task start time: 2024-06-04_14:47:35, for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000576.EDEPSIM_2024-06-04_14:47:35_7995_26450026.log
# Host name: nid008488, Task start time: 2024-06-04_13:54:55, for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000064.EDEPSIM_2024-06-04_13:54:55_2554_26449533.log
# Host name: nid008488, Task start time: 2024-06-04_12:43:13, for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000040.EDEPSIM_2024-06-04_12:43:13_5190_26449533.log
# Host name: nid008493, Task start time: 2024-06-04_12:43:12, for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000080.EDEPSIM_2024-06-04_12:43:12_4320_26449533.log
# Host name: nid008493, Task start time: 2024-06-04_12:43:12, for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000110.EDEPSIM_2024-06-04_12:43:12_3270_26449533.log
# Host name: nid008561, Task start time: 2024-06-04_14:23:28, for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000285.EDEPSIM_2024-06-04_14:23:28_9963_26449534.log
# Host name: nid008404, Task start time: 2024-06-04_14:57:53, for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000477.EDEPSIM_2024-06-04_14:57:53_7585_26450026.log
# Host name: nid008572, Task start time: 2024-06-04_13:03:52, for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000141.EDEPSIM_2024-06-04_13:03:52_5978_26449533.log
# Host name: nid008284, Task start time: 2024-06-04_13:36:45, for tasks longer than 20.8 minutes in file MiniRun5_1E19_RHC.convert2h5.0000422.EDEPSIM_2024-06-04_13:36:45_8607_26450026.log

# %%
import os
import pandas as pd
from IPython.display import display

def parse_log_file(log_file_path):
    data = {
        'file_index': None,
        'input_file': None,
        'output_file': None,
        'log_file': log_file_path,
        'sim_start_time': None,
        'task_start_time': None,
        'elapsed_time(s)': None,
        'task_end_time': None,
        'random_seed': None,
        'job_id': None,
        'host_name': None,
        'gpu_device_id': None,
        'peak_gpu_memory_used': None,
        'gpu_memory_start': None,
        'gpu_memory_end': None,
        'job_completed': False,
        'job_error_msg': None
    }
    
    gpu_memory_usage = []
    with open(log_file_path, 'r') as file:
        for line in file:
            if 'Processing file:' in line:
                parts = line.split(',')
                data['input_file'] = parts[0].split(': ')[1].strip()
                data['sim_start_time'] = parts[2].split('Sim Start Time: ')[1].strip()
                data['task_start_time'] = parts[3].split('Task Start Time: ')[1].strip()
                data['random_seed'] = parts[4].split(':')[-1].strip()
                data['host_name'] = parts[5].split(':')[-1].strip()
                data['file_index'] = parts[6].split(':')[-1].strip()
                data['job_id'] = parts[7].split(':')[-1].strip()
                data['log_file'] = parts[8].split(': ')[1].strip()
            elif 'larnd-sim output file:' in line:
                data['output_file'] = line.split(': ')[1].strip()
            elif 'Elapsed time:' in line:
                elapsed_time_str = line.split(': ')[1].strip()
                try:
                    data['elapsed_time(s)'] = float(elapsed_time_str.replace(' s', ''))
                    data['job_completed'] = True
                except ValueError:
                    data['elapsed_time(s)'] = None

            elif 'End Time:' in line:
                data['task_end_time'] = line.split(': ')[1].strip()
            elif 'MiB' in line and 'memory.used' not in line:
                parts = line.strip().split(', ')
                if 'GPU-' in line:
                    gpu_id = parts[-1].strip()
                    memory_used_str = parts[-2].strip().split()[0]
                    try:
                        memory_used = int(memory_used_str)
                        if not data['gpu_device_id']:
                            data['gpu_device_id'] = gpu_id
                        if memory_used != 0:
                            gpu_memory_usage.append(memory_used)
                    except ValueError:
                        continue  # Skip lines where conversion fails
            elif 'OutOfMemoryError' in line:
                data['job_error_msg'] = 'OutOfMemoryError'
            elif 'CudaAPIError' in line:
                data['job_error_msg'] = 'CudaAPIError'
    
    if gpu_memory_usage:
        data['gpu_memory_start'] = gpu_memory_usage[0]
        data['gpu_memory_end'] = gpu_memory_usage[-1]
        data['peak_gpu_memory_used'] = max(gpu_memory_usage)

    return data

def get_file_size_in_mb(file_path):
    if file_path and os.path.exists(file_path):
        try:
            return os.path.getsize(file_path) / (1024 * 1024)
        except FileNotFoundError:
            return 0
    return 0

def collect_data(folder_path):
    all_data = []

    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.log'):
                full_path = os.path.join(root, file)
                parsed_data = parse_log_file(full_path)
                all_data.append(parsed_data)

    df = pd.DataFrame(all_data)
    df = df.drop_duplicates(subset='log_file', keep='first')
    
    if not df.empty:
        df['input_file_size_mb'] = df['input_file'].apply(get_file_size_in_mb)
        df['output_file_size_mb'] = df['output_file'].apply(get_file_size_in_mb)
        df['file_index'] = df['file_index'].astype(int)
        df.sort_values(by='file_index', inplace=True)

    return df

# Path to your data folder
folder_path = '/pscratch/sd/m/madan12/DUNE/nesap-develop/larnd-sim-output-80GB/'
# Generate the DataFrame
experiments_df = collect_data(folder_path)

# Display the DataFrame to check its contents
display(experiments_df.head())

# Save the DataFrame to a CSV file
experiments_df.to_csv('DUNE_all.csv', index=False)

# Optionally, specify a different path to save the CSV
# experiments_df.to_csv('/pscratch/sd/m/madan12/DUNE/larnd-sim-output-80GB-v2/experiments_summary.csv', index=False)
# Out:
#      file_index                                         input_file  \
# 461           0  /dvs_ro/cfs/cdirs/dune/www/data/2x2/simulation...
# 373           1  /dvs_ro/cfs/cdirs/dune/www/data/2x2/simulation...
# 769           2  /dvs_ro/cfs/cdirs/dune/www/data/2x2/simulation...
# 866           3  /dvs_ro/cfs/cdirs/dune/www/data/2x2/simulation...
# 700           4  /dvs_ro/cfs/cdirs/dune/www/data/2x2/simulation...
#
#                                            output_file  \
# 461  /pscratch/sd/m/madan12/DUNE/nesap-develop/larn...
# 373  /pscratch/sd/m/madan12/DUNE/nesap-develop/larn...
# 769  /pscratch/sd/m/madan12/DUNE/nesap-develop/larn...
# 866  /pscratch/sd/m/madan12/DUNE/nesap-develop/larn...
# 700  /pscratch/sd/m/madan12/DUNE/nesap-develop/larn...
#
#                                               log_file       sim_start_time  \
# 461  /pscratch/sd/m/madan12/DUNE/nesap-develop/larn...  2024-06-04_12:43:11
# 373  /pscratch/sd/m/madan12/DUNE/nesap-develop/larn...  2024-06-04_12:43:11
# 769  /pscratch/sd/m/madan12/DUNE/nesap-develop/larn...  2024-06-04_12:43:11
# 866  /pscratch/sd/m/madan12/DUNE/nesap-develop/larn...  2024-06-04_12:43:11
# 700  /pscratch/sd/m/madan12/DUNE/nesap-develop/larn...  2024-06-04_12:43:11
#
#          task_start_time  elapsed_time(s)        task_end_time random_seed  \
# 461  2024-06-04_12:43:12          1215.66  2024-06-04 13:03:34        1281
# 373  2024-06-04_13:03:34          1115.89  2024-06-04 13:22:13        9718
# 769  2024-06-04_13:22:13          1171.60  2024-06-04 13:41:48         685
# 866  2024-06-04_13:41:48          1117.56  2024-06-04 14:00:28        7214
# 700  2024-06-04_14:00:28          1125.78  2024-06-04 14:19:17        1936
#
#        job_id  host_name                             gpu_device_id  \
# 461  26449533  nid008405  GPU-d563c618-f06c-b427-d109-689a6229ae83
# 373  26449533  nid008405  GPU-d563c618-f06c-b427-d109-689a6229ae83
# 769  26449533  nid008405  GPU-d563c618-f06c-b427-d109-689a6229ae83
# 866  26449533  nid008405  GPU-d563c618-f06c-b427-d109-689a6229ae83
# 700  26449533  nid008405  GPU-d563c618-f06c-b427-d109-689a6229ae83
#
#      peak_gpu_memory_used  gpu_memory_start  gpu_memory_end  job_completed  \
# 461                 80225               459           71879           True
# 373                 80225               491           71879           True
# 769                 80225               495           71879           True
# 866                 80225               483           71879           True
# 700                 77467               459           71879           True
#
#     job_error_msg  input_file_size_mb  output_file_size_mb
# 461          None           21.802216          1178.863121
# 373          None           24.258011          1229.751266
# 769          None           26.940857          1311.050911
# 866          None           18.479630          1126.957649
# 700          None           19.218002          1132.551842

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'experiments_df' is already loaded and contains the 'peak_memory_used', 'elapsed_time', and 'host_name' columns
# Filter the DataFrame to include only rows where 'elapsed_time' is not null
filtered_df = experiments_df.dropna(subset=['elapsed_time(s)'])

plt.figure(figsize=(14, 6))  # Set the figure size
sns.lineplot(data=filtered_df, x='file_index', y='peak_gpu_memory_used', hue='host_name', marker='o', legend='full')
plt.title('Peak GPU Memory Used Across the File Index (Tasks/Jobs Completed)', fontsize=20)  # Title of the plot
plt.xlabel('File Index', fontsize=20)  # X-axis label
plt.ylabel('Peak Memory Used (MiB)', fontsize=20)  # Y-axis label
plt.grid(True)  # Enable grid for easier readability
#plt.legend(title='Host Name', loc='upper right')  # Add a legend with a title and move it to a suitable position
plt.legend(title='Host Name', loc='upper right', bbox_to_anchor=(1.125, 1.1))  # Place legend at top outside

# Increase the size of x-ticks and y-ticks
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

# Display and save the plot
plot = os.path.join(folder_path, 'DUNE_peak_memory_40GB.png')
plt.savefig(plot, dpi=200)
plt.show()

# %%
# Assume elapsed_times is already filled from the previous process_log_files function
valid_elapsed_times = [time for time in elapsed_times if time > 0]

# Create a box plot for valid elapsed time values
plt.figure(figsize=(12, 6))
plt.boxplot(valid_elapsed_times)
plt.title('Job Duration', fontsize=22)
plt.ylabel('Time (sec)', fontsize=22)
plt.xticks([1], ['Job Duration'], fontsize=22)
plt.xticks(fontsize=16) 
plt.yticks(fontsize=16)
plt.grid(True)

# Calculate statistics for valid elapsed time values
valid_mean_elapsed_time = np.mean(valid_elapsed_times)
valid_median_elapsed_time = np.median(valid_elapsed_times)
valid_stdev_elapsed_time = np.std(valid_elapsed_times)
valid_min_elapsed_time = np.min(valid_elapsed_times)
valid_max_elapsed_time = np.max(valid_elapsed_times)

# Set the number of standard deviations for the threshold
num_stdev = 2  # Change this to your desired number of standard deviations

# Calculate the lower and upper bounds for the threshold
lower_bound = valid_mean_elapsed_time - num_stdev * valid_stdev_elapsed_time
upper_bound = valid_mean_elapsed_time + num_stdev * valid_stdev_elapsed_time

# Count values outside the threshold range
count_outside_threshold = sum(1 for time in valid_elapsed_times if time < lower_bound or time > upper_bound)

# Add statistics text to the plot
stats_text = (
    f"Number of Jobs: {total_files}\n"
    f"Mean: {valid_mean_elapsed_time:.2f} sec\n"
    f"Median: {valid_median_elapsed_time:.2f} sec\n"
    f"StDev: {valid_stdev_elapsed_time:.2f} sec\n"
    f"Min: {valid_min_elapsed_time:.2f} sec\n"
    f"Max: {valid_max_elapsed_time:.2f} sec\n"
    f"Num. Failed Jobs: {total_files_failed}\n\n"
)
plt.text(0.68, 0.35, stats_text, transform=plt.gca().transAxes, bbox=dict(facecolor='white', alpha=0.5, edgecolor='none'), fontsize=20)
# Adding text inside the plot near the bottom
plt.text(0.66, 0.3, f"Time outside {num_stdev} StDev: {count_outside_threshold} values", color='purple', transform=plt.gca().transAxes, fontsize=14)

# # Saving the plot
# results_folder = 'Results-Aug2023'  # Adjust as necessary
# if not os.path.exists(results_folder):
#     os.makedirs(results_folder)
# job_duration_plot_path = os.path.join(results_folder, 'job_duration_boxplot.png')
# plt.savefig(job_duration_plot_path, dpi=200)
# plt.show()

plot = os.path.join(folder_path, 'DUNE_job_duration_40GB_boxplot.png')
plt.savefig(plot, dpi=200)

# Print the number of valid elapsed times
print("Number of valid elapsed times values:", len(valid_elapsed_times))

# Print the count of values outside the threshold range
print(f"Number of elapsed time values outside {num_stdev} standard deviations: {count_outside_threshold}")
# Out:
# Number of valid elapsed times values: 840
# Number of elapsed time values outside 2 standard deviations: 36

# %%
############ Keep to check duplicate ########

# Load the CSV file
df = pd.read_csv('DUNE_all.csv')

# Display basic information and the first few rows of the DataFrame
df.info()
#df.head()

# # # Check for duplicates in the 'log_file' column
# # duplicate_rows = df[df['log_file'].duplicated(keep=False)]
# # # Show the duplicates if any
# # duplicate_rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   file_index            1000 non-null   int64
#  1   input_file            1000 non-null   object
#  2   output_file           1000 non-null   object
#  3   log_file              1000 non-null   object
#  4   sim_start_time        1000 non-null   object
#  5   task_start_time       1000 non-null   object
#  6   elapsed_time(s)       840 non-null    float64
#  7   task_end_time         1000 non-null   object
#  8   random_seed           1000 non-null   int64
#  9   job_id                1000 non-null   int64
#  10  host_name             1000 non-null   object
#  11  gpu_device_id         1000 non-null   object
#  12  peak_gpu_memory_used  1000 non-null   int64
#  13  gpu_memory_start      1000 non-null   int64
#  14  gpu_memory_end        1000 non-null   int64
#  15  job_completed         1000 non-null   bool
#  16  job_error_msg         160 non-null    object
#  17  input_file_size_mb    1000 non-null   float64
#  18  output_file_size_mb   1000 non-null   float64
# dtypes: bool(1), float64(3), int64(6), object(9)
# memory usage: 141.7+ KB

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# Load the CSV file
df = pd.read_csv('DUNE_all.csv')

# Display basic information and the first few rows of the DataFrame
#df.info()
#print(df.head())

# Ensure task_start_time and task_end_time are in datetime format
df['task_start_time'] = pd.to_datetime(df['task_start_time'], format='%Y-%m-%d_%H:%M:%S')
df['task_end_time'] = pd.to_datetime(df['task_end_time'], format='%Y-%m-%d %H:%M:%S')

# Calculate the job duration only for rows with valid elapsed_time(s)
df['job_duration'] = df.apply(lambda row: row['task_end_time'] - row['task_start_time'] if not pd.isnull(row['elapsed_time(s)']) else pd.NaT, axis=1)

# Convert the job_duration to minutes for easier comparison if needed
df['job_duration_minutes'] = df['job_duration'].dt.total_seconds() / 60

# Calculate statistics
elapsed_times_min = df['job_duration_minutes'].dropna()
mean_duration = np.mean(elapsed_times_min)
median_duration = np.median(elapsed_times_min)
std_duration = np.std(elapsed_times_min)
min_duration = np.min(elapsed_times_min)
max_duration = np.max(elapsed_times_min)
total_files = len(df)
total_files_failed = df['elapsed_time(s)'].isnull().sum()

# Add statistics text to the plot
stats_text_job_duration = (
    f"Mean: {mean_duration:.2f} min\n"
    f"Median: {median_duration:.2f} min\n"
    f"StDev: {std_duration:.2f} min\n"
    f"Min: {min_duration:.2f} min\n"
    f"Max: {max_duration:.2f} min\n"
    f"\n"
    f"Total Num. of Tasks: {total_files}\n"
    f"Num. Failed Tasks: {total_files_failed}"
)

# Plotting the distribution of job durations using Seaborn
plt.figure(figsize=(10, 6))
# Set font size for the tick labels on both axes
plt.tick_params(axis='both', labelsize=16)
sns.histplot(elapsed_times_min, bins=100, kde=True)
plt.title('Distribution of Job Durations', fontsize=20)
plt.xlabel('Job Duration [minutes]', fontsize=20)
plt.ylabel('Frequency', fontsize=20)
plt.xlim(17, 23)
plt.grid(True)

# Adding the statistics box
plt.text(0.65, 0.6, stats_text_job_duration, transform=plt.gca().transAxes, bbox=dict(facecolor='white', alpha=0.5, edgecolor='none'), fontsize=14)
plot = 'DUNE_job_duration.png'
plt.savefig(plot, dpi=200)
plt.show()

# %% [markdown]
# ### Now 100 failed jobs are submitted using 80GP GPUs bandwith memory!

# %%
from IPython.display import clear_output
clear_output(wait=False)
#!ls

# %%
# Initialize global variables
total_files = 0
total_files_processed = 0
total_elasped_time = 0
total_files_failed = 0
elapsed_times = []
files_without_elapsed_time = []

output_file_path = "40GB_FailedJob_100.txt"

def process_log_files(directory):
    global total_files, total_files_processed, total_elasped_time, total_files_failed, elapsed_times, files_without_elapsed_time
    file_pattern = re.compile(r'edep-sim input file:\s*(.+)')
    time_pattern = re.compile(r'Elapsed time:\s*([\d.]+)\s*s')

    for filename in os.listdir(directory):
        if filename.endswith(".log"):
            with open(os.path.join(directory, filename), 'r') as file:
                input_file_found = False
                elapsed_time_found = False
                for line in file:
                    file_match = file_pattern.search(line)
                    if file_match:
                        full_path = file_match.group(1)
                        input_file = os.path.basename(full_path)  # Extract file name from the full path
                        # directory_path = os.path.dirname(full_path)
                        # full_path = os.path.join(directory_path, input_file)
                        input_file_found = True
                        total_files_processed += 1

                    time_match = time_pattern.search(line)
                    if time_match:
                        elapsed_time = float(time_match.group(1))  # No conversion to minutes
                        elapsed_times.append(elapsed_time)
                        elapsed_time_found = True
                        total_elasped_time += 1
                        #print(f"{input_file}: Elapsed time: {elapsed_time:.2f} sec")
                
                if not elapsed_time_found and input_file_found:
                    #files_without_elapsed_time.append(input_file)
                    files_without_elapsed_time.append(full_path)

    # Calculate statistics for Job Duration in seconds
    if elapsed_times:
        mean_job_duration = np.mean(elapsed_times)
        median_job_duration = np.median(elapsed_times)
        stdev_job_duration = np.std(elapsed_times)
        min_job_duration = np.min(elapsed_times)
        max_job_duration = np.max(elapsed_times)
    else:
        mean_job_duration = median_job_duration = stdev_job_duration = min_job_duration = max_job_duration = 0.0

    total_files = total_files_processed
    total_files_failed = total_files - total_elasped_time
    print("\n********** Jobs Information **********")
    print(f"Total number of input files processed: {total_files}")
    print(f"Total number of Jobs completed: {total_elasped_time}")
    print(f"Total number of Jobs failed: {total_files_failed}")

    print("\n********** Statistics **********")
    print(f"Mean Job Duration: {mean_job_duration:.2f} sec")
    print(f"Median Job Duration: {median_job_duration:.2f} sec")
    print(f"Standard Deviation of Job Duration: {stdev_job_duration:.2f} sec")
    print(f"Minimum Job Duration: {min_job_duration:.2f} sec")
    print(f"Maximum Job Duration: {max_job_duration:.2f} sec")

    # # Print files without elapsed time
    # if files_without_elapsed_time:
    #     #print("\nFiles without 'Elapsed time':")
    #     print("\nFailed Job Input Files:")
    #     for file in files_without_elapsed_time:
    #         print(file)

folder_path = '/pscratch/sd/m/madan12/DUNE/larnd-sim-output-80GB/'
process_log_files(folder_path)

# # Sort the files without elapsed time
# files_without_elapsed_time.sort()

# # Open the file in write mode ('w')
# with open(output_file_path, "w") as output_file:
#     # Write sorted files without elapsed time to the file
#     if files_without_elapsed_time:
#         output_file.write("Files without 'Elapsed time' (sorted):\n")
#         for file in files_without_elapsed_time:
#             output_file.write(file + "\n")

# # Print a message indicating that the output has been written to the file
# print(f"Output has been written to '{output_file_path}'")
# Out:
# ********** Jobs Information **********
# Total number of input files processed: 100
# Total number of Jobs completed: 100
# Total number of Jobs failed: 0
#
# ********** Statistics **********
# Mean Job Duration: 304.51 sec
# Median Job Duration: 303.30 sec
# Standard Deviation of Job Duration: 17.78 sec
# Minimum Job Duration: 264.58 sec
# Maximum Job Duration: 366.89 sec

# %%
# Assuming 'elapsed_times' contains the job durations from the processed log files
if elapsed_times:
    # Filter job duration values greater than 0
    valid_job_durations = [duration for duration in elapsed_times if duration > 0]

    # Create the plot
    plt.figure(figsize=(10, 6))
    sns.histplot(valid_job_durations, bins=100, kde=True)  # Set bins or let seaborn decide

    plt.xlabel('Job Duration [seconds]', fontsize=20)
    plt.xlim(200, 400)
    plt.ylabel('Number of Tasks', fontsize=20)
    #plt.title('Histogram of Job Durations', fontsize=20)

    # Set font size for the tick labels on both axes
    plt.tick_params(axis='both', labelsize=16)
    
    # Add statistics text to the plot
    stats_text_job_duration = (
        f"Mean: {np.mean(valid_job_durations):.2f} sec\n"
        f"Median: {np.median(valid_job_durations):.2f} sec\n"
        f"StDev: {np.std(valid_job_durations):.2f} sec\n"
        f"Min: {np.min(valid_job_durations):.2f} sec\n"
        f"Max: {np.max(valid_job_durations):.2f} sec\n"
        f"\n"
        f"Total Num. of Tasks: {total_files}\n"
        f"Num. Failed Tasks: {total_files_failed}"
    )
    plt.text(0.65, 0.6, stats_text_job_duration, transform=plt.gca().transAxes, bbox=dict(facecolor='white', alpha=0.5, edgecolor='none'), fontsize=14)
    
    # Display and save the plot
    plot = os.path.join(folder_path, 'DUNE_job_duration_80GB.png')
    plt.savefig(plot, dpi=200)
    plt.show()

else:
    print("No job duration data available to plot.")

# %%
import os

def check_host_for_long_tasks(log_file_path):
    filename = os.path.basename(log_file_path)  # Extract the filename once at the beginning

    with open(log_file_path, 'r') as file:
        host_name = None
        elapsed_time_over = False
        for line in file:
            if 'Processing file:' in line:
                parts = line.split(',')
                # Extract the host name directly from the predefined position
                host_name = parts[5].split(':')[-1].strip()

            elif 'Elapsed time:' in line:
                try:
                    # Convert the elapsed time to float and check if it's greater than 350 seconds
                    elapsed_time = float(line.split(': ')[1].strip().split(' ')[0])
                    if elapsed_time > 325:
                        elapsed_time_over = True
                        # Break if both host name and elapsed time condition are met
                        if host_name is not None:
                            print(f'Host name: {host_name} for tasks longer than 325 seconds in file {filename}')
                            break
                except ValueError:
                    # Handle cases where the conversion to float fails
                    #print(f"Error parsing elapsed time in file {filename}: {line}")
                    print(f"Error parsing elapsed time in file {log_file_path}: {line}")

def process_all_logs(directory):
    for filename in os.listdir(directory):
        if filename.endswith('.log'):  # Assuming all log files end with .log
            log_file_path = os.path.join(directory, filename)
            check_host_for_long_tasks(log_file_path)

# Directory path containing the log files
folder_path = '/pscratch/sd/m/madan12/DUNE/larnd-sim-output-80GB/'
process_all_logs(folder_path)
# Out:
# Host name: nid008385 for tasks longer than 325 seconds in file MiniRun5_1E19_RHC.convert2h5.0000346.EDEPSIM_2024-04-24_16:07:34_683_24737653.log
# Host name: nid008384 for tasks longer than 325 seconds in file MiniRun5_1E19_RHC.convert2h5.0000251.EDEPSIM_2024-04-24_15:51:08_3379_24737653.log
# Host name: nid008392 for tasks longer than 325 seconds in file MiniRun5_1E19_RHC.convert2h5.0000907.EDEPSIM_2024-04-24_15:55:31_4000_24737653.log
# Host name: nid008384 for tasks longer than 325 seconds in file MiniRun5_1E19_RHC.convert2h5.0000192.EDEPSIM_2024-04-24_16:05:54_2752_24737653.log
# Host name: nid008385 for tasks longer than 325 seconds in file MiniRun5_1E19_RHC.convert2h5.0000296.EDEPSIM_2024-04-24_15:56:33_3469_24737653.log
# Host name: nid008385 for tasks longer than 325 seconds in file MiniRun5_1E19_RHC.convert2h5.0000477.EDEPSIM_2024-04-24_16:00:13_8679_24737653.log
# Host name: nid008388 for tasks longer than 325 seconds in file MiniRun5_1E19_RHC.convert2h5.0000721.EDEPSIM_2024-04-24_16:06:53_6174_24737653.log
# Host name: nid008388 for tasks longer than 325 seconds in file MiniRun5_1E19_RHC.convert2h5.0000535.EDEPSIM_2024-04-24_15:56:18_3586_24737653.log
# Host name: nid008389 for tasks longer than 325 seconds in file MiniRun5_1E19_RHC.convert2h5.0000746.EDEPSIM_2024-04-24_16:06:46_273_24737653.log
# Host name: nid008389 for tasks longer than 325 seconds in file MiniRun5_1E19_RHC.convert2h5.0000804.EDEPSIM_2024-04-24_15:56:17_906_24737653.log
# Host name: nid008388 for tasks longer than 325 seconds in file MiniRun5_1E19_RHC.convert2h5.0000567.EDEPSIM_2024-04-24_16:01:14_3526_24737653.log
# Host name: nid008385 for tasks longer than 325 seconds in file MiniRun5_1E19_RHC.convert2h5.0000490.EDEPSIM_2024-04-24_15:46:08_6601_24737653.log

# %%
import os
import pandas as pd
from IPython.display import display

def parse_log_file(log_file_path):
    data = {
        'file_index': None,
        'input_file': None,
        'output_file': None,
        'log_file': log_file_path,
        'sim_start_time': None,
        'task_start_time': None,
        'elapsed_time(s)': None,
        'task_end_time': None,
        'random_seed': None,
        'job_id': None,
        'host_name': None,
        'gpu_device_id': None,
        'peak_gpu_memory_used': None,
        'gpu_memory_start': None,
        'gpu_memory_end': None,
        'job_completed': False,
        'job_error_msg': None
    }
    
    gpu_memory_usage = []
    with open(log_file_path, 'r') as file:
        for line in file:
            if 'Processing file:' in line:
                parts = line.split(',')
                data['input_file'] = parts[0].split(': ')[1].strip()
                data['sim_start_time'] = parts[2].split('Sim Start Time: ')[1].strip()
                data['task_start_time'] = parts[3].split('Task Start Time: ')[1].strip()
                data['random_seed'] = parts[4].split(':')[-1].strip()
                data['host_name'] = parts[5].split(':')[-1].strip()
                data['file_index'] = parts[6].split(':')[-1].strip()
                data['job_id'] = parts[7].split(':')[-1].strip()
                data['log_file'] = parts[8].split(': ')[1].strip()
            elif 'Output file:' in line:
                data['output_file'] = line.split(': ')[1].strip()
            elif 'Elapsed time:' in line:
                elapsed_time_str = line.split(': ')[1].strip()
                try:
                    data['elapsed_time(s)'] = float(elapsed_time_str.replace(' s', ''))
                    data['job_completed'] = True
                except ValueError:
                    data['elapsed_time(s)'] = None

            elif 'End Time:' in line:
                data['task_end_time'] = line.split(': ')[1].strip()
            elif 'MiB' in line and 'memory.used' not in line:
                parts = line.strip().split(', ')
                if 'GPU-' in line:
                    gpu_id = parts[-1].strip()
                    memory_used_str = parts[-2].strip().split()[0]
                    try:
                        memory_used = int(memory_used_str)
                        if not data['gpu_device_id']:
                            data['gpu_device_id'] = gpu_id
                        if memory_used != 0:
                            gpu_memory_usage.append(memory_used)
                    except ValueError:
                        continue  # Skip lines where conversion fails
            elif 'OutOfMemoryError' in line:
                data['job_error_msg'] = 'OutOfMemoryError'
    
    if gpu_memory_usage:
        data['gpu_memory_start'] = gpu_memory_usage[0]
        data['gpu_memory_end'] = gpu_memory_usage[-1]
        data['peak_gpu_memory_used'] = max(gpu_memory_usage)

    return data

def get_file_size_in_mb(file_path):
    try:
        return os.path.getsize(file_path) / (1024 * 1024)
    except FileNotFoundError:
        return 0

def collect_data(folder_path):
    all_data = []

    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.log'):
                full_path = os.path.join(root, file)
                parsed_data = parse_log_file(full_path)
                all_data.append(parsed_data)

    df = pd.DataFrame(all_data)
    df = df.drop_duplicates(subset='log_file', keep='first')
    
    if not df.empty:
        df['input_file_size_mb'] = df['input_file'].apply(get_file_size_in_mb)
        df['output_file_size_mb'] = df['output_file'].apply(get_file_size_in_mb)
        df['file_index'] = df['file_index'].astype(int)
        df.sort_values(by='file_index', inplace=True)

    return df

# Path to your data folder
folder_path = '/pscratch/sd/m/madan12/DUNE/larnd-sim-output-80GB/'

# Generate the DataFrame
experiments_df = collect_data(folder_path)

# Display the DataFrame to check its contents
display(experiments_df.head())

# Save the DataFrame to a CSV file
experiments_df.to_csv('DUNE_80GB.csv', index=False)

# Display
# Optionally, specify a different path to save the CSV
# experiments_df.to_csv('/pscratch/sd/m/madan12/DUNE/larnd-sim-output-80GB-v2/experiments_summary.csv', index=False)
# Out:
#     file_index                                         input_file  \
# 75           0  /dvs_ro/cfs/cdirs/dune/www/data/2x2/simulation...
# 77           1  /dvs_ro/cfs/cdirs/dune/www/data/2x2/simulation...
# 73           2  /dvs_ro/cfs/cdirs/dune/www/data/2x2/simulation...
# 10           3  /dvs_ro/cfs/cdirs/dune/www/data/2x2/simulation...
# 58           4  /dvs_ro/cfs/cdirs/dune/www/data/2x2/simulation...
#
#                                           output_file  \
# 75  /pscratch/sd/m/madan12/DUNE/larnd-sim-output-8...
# 77  /pscratch/sd/m/madan12/DUNE/larnd-sim-output-8...
# 73  /pscratch/sd/m/madan12/DUNE/larnd-sim-output-8...
# 10  /pscratch/sd/m/madan12/DUNE/larnd-sim-output-8...
# 58  /pscratch/sd/m/madan12/DUNE/larnd-sim-output-8...
#
#                                              log_file       sim_start_time  \
# 75  /pscratch/sd/m/madan12/DUNE/larnd-sim-output-8...  2024-04-24_15:46:05
# 77  /pscratch/sd/m/madan12/DUNE/larnd-sim-output-8...  2024-04-24_15:46:05
# 73  /pscratch/sd/m/madan12/DUNE/larnd-sim-output-8...  2024-04-24_15:46:05
# 10  /pscratch/sd/m/madan12/DUNE/larnd-sim-output-8...  2024-04-24_15:46:05
# 58  /pscratch/sd/m/madan12/DUNE/larnd-sim-output-8...  2024-04-24_15:46:05
#
#         task_start_time  elapsed_time(s)        task_end_time random_seed  \
# 75  2024-04-24_15:46:07           308.48  2024-04-24 15:51:21        2640
# 77  2024-04-24_15:51:21           288.07  2024-04-24 15:56:11        4833
# 73  2024-04-24_15:56:11           305.83  2024-04-24 16:01:19        5927
# 10  2024-04-24_16:01:19           296.82  2024-04-24 16:06:18        7996
# 58  2024-04-24_16:06:18           286.03  2024-04-24 16:11:07         854
#
#       job_id  host_name                             gpu_device_id  \
# 75  24737653  nid008384  GPU-bf8b6fdd-270d-e57e-9f48-b985dbf75ab4
# 77  24737653  nid008384  GPU-bf8b6fdd-270d-e57e-9f48-b985dbf75ab4
# 73  24737653  nid008384  GPU-bf8b6fdd-270d-e57e-9f48-b985dbf75ab4
# 10  24737653  nid008384  GPU-bf8b6fdd-270d-e57e-9f48-b985dbf75ab4
# 58  24737653  nid008384  GPU-bf8b6fdd-270d-e57e-9f48-b985dbf75ab4
#
#     peak_gpu_memory_used  gpu_memory_start  gpu_memory_end  job_completed  \
# 75                 78715                15           65829           True
# 77                 78669               499           65825           True
# 73                 78669               503           65825           True
# 10                 78667               499           65831           True
# 58                 65863               499           65831           True
#
#    job_error_msg  input_file_size_mb  output_file_size_mb
# 75          None           31.430527           919.235977
# 77          None           31.259140           899.042980
# 73          None           35.420151           977.694580
# 10          None           30.677505           890.008003
# 58          None           32.103470           915.276955

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming 'experiments_df' is already loaded and contains the 'peak_memory_used', 'elapsed_time', and 'host_name' columns
# Filter the DataFrame to include only rows where 'elapsed_time' is not null
#filtered_df = experiments_df.dropna(subset=['elapsed_time(s)'])
plt.figure(figsize=(14, 6))  # Set the figure size
sns.lineplot(data=experiments_df, x='file_index', y='peak_gpu_memory_used', hue='host_name', marker='o', legend='full')
plt.title('Peak GPU Memory Used Across the File Index (Tasks/Jobs Completed)', fontsize=20)  # Title of the plot
plt.xlabel('File Index', fontsize=20)  # X-axis label
plt.ylabel('Peak Memory Used (MiB)', fontsize=20)  # Y-axis label
plt.grid(True)  # Enable grid for easier readability
#plt.legend(title='Host Name', loc='upper right')  # Add a legend with a title and move it to a suitable position
plt.legend(title='Host Name', loc='upper right', bbox_to_anchor=(1.125, 1.0))  # Place legend at top outside

# Increase the size of x-ticks and y-ticks
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)

# Display and save the plot
plot = os.path.join(folder_path, 'DUNE_peak_memory_80GB.png')
plt.savefig(plot, dpi=200)
plt.show()

# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

def parse_log_file(log_file_path):
    entries = []
    time_seconds = 0  # Start time counter at 0 seconds
    elapsed_time_present = False  # Flag to check if elapsed time is present in the log file
    with open(log_file_path, 'r') as file:
        file_index = None
        host_name = None
        for line in file:
            if 'Elapsed time:' in line and 's' in line:
                try:
                    # Attempt to extract and convert elapsed time to a float
                    elapsed_time = float(line.split('Elapsed time:')[1].strip().replace('s', '').strip())
                    if elapsed_time > 0:
                        elapsed_time_present = True
                except ValueError:
                    continue  # Skip lines where conversion fails

            if 'Processing file:' in line:
                parts = line.split(',')
                try:
                    file_index = int(parts[6].split(':')[-1].strip())
                    host_name = parts[5].split(':')[-1].strip()
                except (ValueError, IndexError):
                    file_index = None
                    host_name = None
            elif 'MiB' in line and 'memory.used' not in line:
                try:
                    memory_used = int(line.strip().split(', ')[-2].split()[0])
                    entries.append({
                        'time_seconds': time_seconds,
                        'memory_used': memory_used,
                        'file_index': file_index,
                        'host_name': host_name,
                        'log_file': os.path.basename(log_file_path)
                    })
                    time_seconds += 5  # Simulate 5 seconds increment
                except ValueError:
                    pass
    return entries, elapsed_time_present

def collect_data(folder_path):
    all_data = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            if file.endswith('.log'):
                full_path = os.path.join(root, file)
                try:
                    parsed_data, elapsed_time_present = parse_log_file(full_path)
                    if elapsed_time_present:
                        all_data.extend(parsed_data)
                except Exception as e:
                    print(f"Error processing file {full_path}: {e}")
    return pd.DataFrame(all_data)

folder_path = '/pscratch/sd/m/madan12/DUNE/larnd-sim-output-80GB/'

# Generate the DataFrame
experiments_df = collect_data(folder_path)

# Set up a 10x10 grid of plots
fig, axes = plt.subplots(10, 10, figsize=(25, 25), sharex=True, sharey=True)
fig.suptitle('Memory Usage Over Time for Each Log File with Valid Elapsed Time', fontsize=16)

# Flatten axes array for easier iteration
axes = axes.flatten()

# Plot each log file's memory usage on a separate subplot
for i, (key, group) in enumerate(experiments_df.groupby('file_index')):
    if i < 100:  # Ensure we do not exceed 100 subplots
        sns.lineplot(ax=axes[i], data=group, x='time_seconds', y='memory_used')
        axes[i].set_title(f"File Index: {key}", fontsize=8)
        axes[i].set_xlabel('')
        axes[i].set_ylabel('')

# Hide any unused axes if there are fewer than 100 log files
for j in range(i + 1, 100):
    axes[j].set_visible(False)

plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust layout to make room for the main title

# Save the plot with error handling
plot = os.path.join(folder_path, 'DUNE_memory_distribution_80GB.png')
try:
    plt.savefig(plot, dpi=200)
    print(f"Plot saved successfully at {plot}")
except Exception as e:
    print(f"Failed to save plot: {e}")

plt.show()
# Out:
# Plot saved successfully at /pscratch/sd/m/madan12/DUNE/larnd-sim-output-80GB/DUNE_memory_distribution_80GB.png

# %%
# Assume elapsed_times is already filled from the previous process_log_files function
valid_elapsed_times = [time for time in elapsed_times if time > 0]

# Create a box plot for valid elapsed time values
plt.figure(figsize=(12, 6))
plt.boxplot(valid_elapsed_times)
plt.title('Job Duration', fontsize=22)
plt.ylabel('Time (minutes)', fontsize=22)
plt.xticks([1], ['Job Duration'], fontsize=22)
plt.xticks(fontsize=16) 
plt.yticks(fontsize=16)
plt.grid(True)

# Calculate statistics for valid elapsed time values
valid_mean_elapsed_time = np.mean(valid_elapsed_times)
valid_median_elapsed_time = np.median(valid_elapsed_times)
valid_stdev_elapsed_time = np.std(valid_elapsed_times)
valid_min_elapsed_time = np.min(valid_elapsed_times)
valid_max_elapsed_time = np.max(valid_elapsed_times)

# Set the number of standard deviations for the threshold
num_stdev = 2  # Change this to your desired number of standard deviations

# Calculate the lower and upper bounds for the threshold
lower_bound = valid_mean_elapsed_time - num_stdev * valid_stdev_elapsed_time
upper_bound = valid_mean_elapsed_time + num_stdev * valid_stdev_elapsed_time

# Count values outside the threshold range
count_outside_threshold = sum(1 for time in valid_elapsed_times if time < lower_bound or time > upper_bound)

# Add statistics text to the plot
stats_text = (
    f"Number of Jobs: {total_files}\n"
    f"Mean: {valid_mean_elapsed_time:.2f} min\n"
    f"Median: {valid_median_elapsed_time:.2f} min\n"
    f"StDev: {valid_stdev_elapsed_time:.2f} min\n"
    f"Min: {valid_min_elapsed_time:.2f} min\n"
    f"Max: {valid_max_elapsed_time:.2f} min\n"
    f"Num. Failed Jobs: {total_files_failed}\n\n"
)
plt.text(0.68, 0.35, stats_text, transform=plt.gca().transAxes, bbox=dict(facecolor='white', alpha=0.5, edgecolor='none'), fontsize=20)
# Adding text inside the plot near the bottom
plt.text(0.66, 0.3, f"Time outside {num_stdev} StDev: {count_outside_threshold} values", color='purple', transform=plt.gca().transAxes, fontsize=14)

# # Saving the plot
# results_folder = 'Results-Aug2023'  # Adjust as necessary
# if not os.path.exists(results_folder):
#     os.makedirs(results_folder)
# job_duration_plot_path = os.path.join(results_folder, 'job_duration_boxplot.png')
# plt.savefig(job_duration_plot_path, dpi=200)
# plt.show()

plot = os.path.join(folder_path, 'DUNE_job_duration_boxplot.png')
plt.savefig(plot, dpi=200)

# Print the number of valid elapsed times
print("Number of valid elapsed times values:", len(valid_elapsed_times))

# Print the count of values outside the threshold range
print(f"Number of elapsed time values outside {num_stdev} standard deviations: {count_outside_threshold}")
# Out:
# Number of valid elapsed times values: 100
# Number of elapsed time values outside 2 standard deviations: 7

# %%
# ####### DO NOT REMOVE ##########
# import pandas as pd
# import subprocess
# import os

# def get_slurm_job_info(job_id):
#     command = f"sacct -j {job_id} -n -p -X -o 'NodeList,Start,End'"
#     result = subprocess.run(command, shell=True, capture_output=True, text=True)
#     lines = result.stdout.strip().split('\n')
#     data = [line.split('|')[:-1] for line in lines if line]
#     return pd.DataFrame(data, columns=['node_name', 'start_time', 'end_time'])

# def get_file_size_in_mb(filepath):
#     if os.path.exists(filepath):
#         return os.path.getsize(filepath) / (2**20)  # Convert bytes to MB
#     return None

# def parse_log_file(log_file_path):
#     with open(log_file_path, 'r') as file:
#         lines = file.readlines()

#     output_file_path = ''
#     random_seed = ''
#     input_file_path = ''
#     for line in lines:
#         if "Output file:" in line:
#             output_file_path = line.split(': ')[1].strip()
#         elif "Random seed:" in line:
#             random_seed = line.split(': ')[1].strip()
#         elif "edep-sim input file:" in line:
#             input_file_path = line.split(': ')[1].strip()

#     input_file_name = os.path.basename(input_file_path)
#     log_file_name = os.path.basename(log_file_path)
#     job_id = log_file_name.replace('.log', '').split('_')[-1]

#     return {
#         'input_file_name': input_file_name,
#         'job_id': job_id,
#         'output_file_path': output_file_path,
#         'log_file_path': log_file_path,
#         'random_seed': random_seed
#     }

# log_files_directory = '/pscratch/sd/m/madan12/DUNE/larnd-sim-output-80GB/'

# input_files_list_path = os.path.join(log_files_directory, 'FailedJob_80GB.txt')
# with open(input_files_list_path, 'r') as file:
#     input_files_full_paths = [os.path.join(log_files_directory, line.strip()) for line in file]

# input_files_map = {os.path.basename(path): path for path in input_files_full_paths}

# log_files = [os.path.join(log_files_directory, f) for f in os.listdir(log_files_directory) if f.endswith('.log')]

# experiments_data = []
# for log_file in log_files:
#     experiments_data.append(parse_log_file(log_file))

# experiments_df = pd.DataFrame(experiments_data)

# if not experiments_df.empty:
#     experiments_df['input_file_size_mb'] = experiments_df['input_file_name'].apply(
#         lambda f: get_file_size_in_mb(input_files_map.get(f, '')))
#     experiments_df['output_file_size_mb'] = experiments_df['output_file_path'].apply(get_file_size_in_mb)

#     prefix = 'MiniRun5_1E19_RHC.convert2h5'
#     filtered_df = experiments_df[experiments_df['input_file_name'].str.startswith(prefix)].copy()

#     if not filtered_df.empty:
#         for index, row in filtered_df.iterrows():
#             slurm_data = get_slurm_job_info(row['job_id'])
#             if not slurm_data.empty:
#                 filtered_df.loc[index, 'node_name'] = ', '.join(slurm_data['node_name'].unique())
#                 start_times = pd.to_datetime(slurm_data['start_time'], errors='coerce')
#                 end_times = pd.to_datetime(slurm_data['end_time'], errors='coerce')
#                 filtered_df.loc[index, 'start_time'] = start_times.min()
#                 filtered_df.loc[index, 'end_time'] = end_times.max()
#                 if pd.notnull(start_times.min()) and pd.notnull(end_times.max()):
#                     filtered_df.loc[index, 'run_time'] = end_times.max() - start_times.min()

#         filtered_df.to_csv('DUNE_80GB.csv', index=False)
#         print(f"Saved filtered_data.csv with {len(filtered_df)} records.")
#     else:
#         print(f"No records found with prefix '{prefix}'.")
# else:
#     print("No data found in log files.")

# %% [markdown]
# #### The error "CUDA_ERROR_ILLEGAL_ADDRESS: an illegal memory access was encountered" occurred during a simulation, possibly due to an issue with memory access or allocation in the CUDA environment.

# %%
******************
RUNNING SIMULATION
******************
Quenching electrons... 0.14 s
Drifting electrons... 0.17 s
Calculating optical responses...Traceback (most recent call last):
  File "/pscratch/sd/m/madan12/DUNE/larnd-sim-example/larnd-sim.venv/bin/simulate_pixels.py", line 7, in <module>
    exec(compile(f.read(), __file__, 'exec'))
  File "/pscratch/sd/m/madan12/DUNE/larnd-sim-example/larnd-sim/cli/simulate_pixels.py", line 762, in <module>
    fire.Fire(run_simulation)
  File "/pscratch/sd/m/madan12/DUNE/larnd-sim-example/larnd-sim.venv/lib/python3.11/site-packages/fire/core.py", line 143, in Fire
    component_trace = _Fire(component, args, parsed_flag_args, context, name)
                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
  File "/pscratch/sd/m/madan12/DUNE/larnd-sim-example/larnd-sim.venv/lib/python3.11/site-packages/fire/core.py", line 477, in _Fire
    component, remaining_args = _CallAndUpdateTrace(
                                ^^^^^^^^^^^^^^^^^^^^
  File "/pscratch/sd/m/madan12/DUNE/larnd-sim-example/larnd-sim.venv/lib/python3.11/site-packages/fire/core.py", line 693, in _CallAndUpdateTrace
    component = fn(*varargs, **kwargs)
                ^^^^^^^^^^^^^^^^^^^^^^
  File "/pscratch/sd/m/madan12/DUNE/larnd-sim-example/larnd-sim/cli/simulate_pixels.py", line 346, in run_simulation
    lightLUT.calculate_light_incidence[BPG,TPB](tracks, lut, light_sim_dat, track_light_voxel)
  File "/pscratch/sd/m/madan12/DUNE/larnd-sim-example/larnd-sim.venv/lib/python3.11/site-packages/numba/cuda/dispatcher.py", line 539, in __call__
    return self.dispatcher.call(args, self.griddim, self.blockdim,
           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
  File "/pscratch/sd/m/madan12/DUNE/larnd-sim-example/larnd-sim.venv/lib/python3.11/site-packages/numba/cuda/dispatcher.py", line 683, in call
    kernel.launch(args, griddim, blockdim, stream, sharedmem)
  File "/pscratch/sd/m/madan12/DUNE/larnd-sim-example/larnd-sim.venv/lib/python3.11/site-packages/numba/cuda/dispatcher.py", line 371, in launch
    wb()
  File "/pscratch/sd/m/madan12/DUNE/larnd-sim-example/larnd-sim.venv/lib/python3.11/site-packages/numba/cuda/args.py", line 62, in <lambda>
    retr.append(lambda: devary.copy_to_host(self.value, stream=stream))
                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
  File "/pscratch/sd/m/madan12/DUNE/larnd-sim-example/larnd-sim.venv/lib/python3.11/site-packages/numba/cuda/cudadrv/devices.py", line 232, in _require_cuda_context
    return fn(*args, **kws)
           ^^^^^^^^^^^^^^^^
  File "/pscratch/sd/m/madan12/DUNE/larnd-sim-example/larnd-sim.venv/lib/python3.11/site-packages/numba/cuda/cudadrv/devicearray.py", line 277, in copy_to_host
    _driver.device_to_host(hostary, self, self.alloc_size,
  File "/pscratch/sd/m/madan12/DUNE/larnd-sim-example/larnd-sim.venv/lib/python3.11/site-packages/numba/cuda/cudadrv/driver.py", line 3145, in device_to_host
    fn(host_pointer(dst), device_pointer(src), size, *varargs)
  File "/pscratch/sd/m/madan12/DUNE/larnd-sim-example/larnd-sim.venv/lib/python3.11/site-packages/numba/cuda/cudadrv/driver.py", line 327, in safe_cuda_api_call
    self._check_ctypes_error(fname, retcode)
  File "/pscratch/sd/m/madan12/DUNE/larnd-sim-example/larnd-sim.venv/lib/python3.11/site-packages/numba/cuda/cudadrv/driver.py", line 395, in _check_ctypes_error
    raise CudaAPIError(retcode, msg)
numba.cuda.cudadrv.driver.CudaAPIError: [700] Call to cuMemcpyDtoH results in UNKNOWN_CUDA_ERROR
Traceback (most recent call last):
  File "cupy_backends/cuda/api/driver.pyx", line 234, in cupy_backends.cuda.api.driver.moduleUnload
  File "cupy_backends/cuda/api/driver.pyx", line 63, in cupy_backends.cuda.api.driver.check_status
cupy_backends.cuda.api.driver.CUDADriverError: CUDA_ERROR_ILLEGAL_ADDRESS: an illegal memory access was encountered
Exception ignored in: 'cupy.cuda.function.Module.__dealloc__'
Traceback (most recent call last):
  File "cupy_backends/cuda/api/driver.pyx", line 234, in cupy_backends.cuda.api.driver.moduleUnload
  File "cupy_backends/cuda/api/driver.pyx", line 63, in cupy_backends.cuda.api.driver.check_status
cupy_backends.cuda.api.driver.CUDADriverError: CUDA_ERROR_ILLEGAL_ADDRESS: an illegal memory access was encountered
# Out:
#   Cell In[19], line 1
#     ******************
#     ^
# SyntaxError: invalid syntax
